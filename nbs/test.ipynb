# %%
from scripts.utils import prepare_dataset

# %%
h5_path = "/home/b5cc/sanjukta.b5cc/st3/datasets/dataset/k562_train_split.h5ad"
