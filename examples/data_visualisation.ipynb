# %%
import scanpy as sc

# Load h5ad file from datasets folder
adata = sc.read_h5ad("../datasets/competition_support_set/competition_train_hvg_2000.h5ad")

# Display basic info about the dataset
print(adata)
